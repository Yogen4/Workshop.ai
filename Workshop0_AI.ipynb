# %% [markdown]
# <a href="https://colab.research.google.com/github/Yogen4/Workshop.ai/blob/main/Workshop0_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def convert_units(conversion_type, value):
    if conversion_type == 1:  #meters to feet
        return value * 3.28084
    elif conversion_type == 2:  #feet to meters
        return value / 3.28084
    elif conversion_type == 3:  #kilograms to pounds
        return value * 2.20462
    elif conversion_type == 4:  #pounds to kilograms
        return value / 2.20462
    elif conversion_type == 5:  #liters to gallons
        return value * 0.264172
    elif conversion_type == 6:  #gallons to liters
        return value / 0.264172
    else:
        return None


def main():
    print("Unit Conversion Program")
    print("Choose a conversion type:")
    print("1. Meters to Feet")
    print("2. Feet to Meters")
    print("3. Kilograms to Pounds")
    print("4. Pounds to Kilograms")
    print("5. Liters to Gallons")
    print("6. Gallons to Liters")

    try:
        choice = int(input("Enter your choice (1-6): "))
        value = float(input("Enter the value to convert: "))

        result = convert_units(choice, value)

        if result is None:
            print("Error: Unsupported conversion type.")
        else:
            print(f"Converted value: {result:.2f}")

    except ValueError:
        print("Error: Please enter a valid numeric value.")


if __name__ == "__main__":
    main()
# Out:
# Unit Conversion Program
# Choose a conversion type:
# 1. Meters to Feet
# 2. Feet to Meters
# 3. Kilograms to Pounds
# 4. Pounds to Kilograms
# 5. Liters to Gallons
# 6. Gallons to Liters
# Enter your choice (1-6): 4
# Enter the value to convert: 920
# Converted value: 417.31

# %%
def calculate_sum(numbers):
    return sum(numbers)

def calculate_average(numbers):
    return sum(numbers) / len(numbers)

def find_maximum(numbers):
    return max(numbers)

def find_minimum(numbers):
    return min(numbers)

def main():
    print("Choose an operation:")
    print("1. Sum")
    print("2. Average")
    print("3. Maximum")
    print("4. Minimum")

    try:
        choice = int(input("Enter your choice (1-4): "))

        user_input = input("Enter numbers: ")
        numbers = list(map(float, user_input.split()))

        if len(numbers) == 0:
            print("Error: The list cannot be empty.")
            return

        if choice == 1:
            result = calculate_sum(numbers)
            print("Sum:", result)
        elif choice == 2:
            result = calculate_average(numbers)
            print("Average:", result)
        elif choice == 3:
            result = find_maximum(numbers)
            print("Maximum:", result)
        elif choice == 4:
            result = find_minimum(numbers)
            print("Minimum:", result)
        else:
            print("Error: Invalid operation selected.")

    except ValueError:
        print("Error: Please enter valid numbers.")


if __name__ == "__main__":
    main()
# Out:
# Choose an operation:
# 1. Sum
# 2. Average
# 3. Maximum
# 4. Minimum
# Enter your choice (1-4): 3
# Enter numbers: 255
# Maximum: 255.0

# %%
def extract_every_other(lst):
    return lst[::2]

numbers = [1, 2, 3, 4, 5, 6]
result = extract_every_other(numbers)
print(result)
# Out:
# [1, 3, 5]

# %%
def get_sublist(lst, start, end):
    return lst[start:end+1]


# Example
numbers = [1, 2, 3, 4, 5, 6]
result = get_sublist(numbers, 2, 4)
print(result)
# Out:
# [3, 4, 5]

# %%
def reverse_list(lst):
    return lst[::-1]

numbers = [1, 2, 3, 4, 5]
reversed_numbers = reverse_list(numbers)
print(reversed_numbers)
# Out:
# [5, 4, 3, 2, 1]

# %%
def get_first_n(lst, n):
    return lst[:n]

numbers = [1, 2, 3, 4, 5]
result = get_first_n(numbers, 3)
print(result)
# Out:
# [1, 2, 3]

# %%
def get_last_n(lst, n):
    return lst[-n:]

numbers = [1, 2, 3, 4, 5]
result = get_last_n(numbers, 2)
print(result)
# Out:
# [4, 5]

# %%
def get_last_n(lst, n):
    return lst[-n:]
numbers = [1, 2, 3, 4, 5]
result = get_last_n(numbers, 2)
print(result)
# Out:
# [4, 5]

# %%
def reverse_skip(lst):
    return lst[-2::-2]

numbers = [1, 2, 3, 4, 5, 6]
result = reverse_skip(numbers)
print(result)
# Out:
# [5, 3, 1]

# %%
def flatten(lst):
    flattened_list = []
    for sublist in lst:
        flattened_list.extend(sublist)
    return flattened_list

nested_list = [[1, 2], [3, 4], [5]]
result = flatten(nested_list)
print(result)
# Out:
# [1, 2, 3, 4, 5]

# %%
def access_nested_element(lst, indices):
    element = lst
    for index in indices:
        element = element[index]
    return element

nested_list = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
indices = [1, 2]
result = access_nested_element(nested_list, indices)
print(result)
# Out:
# 6
